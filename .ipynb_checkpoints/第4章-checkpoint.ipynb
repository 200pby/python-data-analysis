# %% [markdown]
# ## 4.1	数据清洗

# %% [markdown]
# ### 4.1.1	缺失值的检测

# %%
import pandas as pd
import numpy as np
df_na = pd.DataFrame({'Num1':[1, 2, None, 4],
                      'Num2':[5, 6, 7, 8],
                      'Num3':[9, 10, 11, 12],
                      'Num4':[13, 14, np.nan, np.nan]})
df_na
# Out:
#    Num1  Num2  Num3  Num4
# 0   1.0     5     9  13.0
# 1   2.0     6    10  14.0
# 2   NaN     7    11   NaN
# 3   4.0     8    12   NaN

# %%
pd.isnull(df_na)      # 检测数据中是否包含缺失值
# Out:
#     Num1   Num2   Num3   Num4
# 0  False  False  False  False
# 1  False  False  False  False
# 2   True  False  False   True
# 3  False  False  False   True

# %%
pd.notnull(df_na)      # 检测数据中是否不包含缺失值
# Out:
#     Num1  Num2  Num3   Num4
# 0   True  True  True   True
# 1   True  True  True   True
# 2  False  True  True  False
# 3   True  True  True  False

# %%
def missing_values_table(df):
    # 计算每列包含缺失值的数量
    mis_val = df.isnull().sum()
    # 计算所有列缺失值⽐例
    mis_val_percent = df.isnull().sum() / len(df) * 100
    # 将数量和比例组合成DataFrame类的对象
    mis_val_table = pd.DataFrame({'数量':mis_val, '占比(%)':mis_val_percent})
    # 按照缺失值的数量降序排列
    mis_val_table_sorted = mis_val_table.sort_values('数量', ascending=False)
    return mis_val_table_sorted

# %%
missing_values_table(df_na)   # 统计缺失值的数量和占比情况
# Out:
#       数量  占比(%)
# Num4   2   50.0
# Num1   1   25.0
# Num2   0    0.0
# Num3   0    0.0

# %% [markdown]
# ### 4.1.2	缺失值的处理

# %%
df_na.dropna()      # 删除包含缺失值的行
# Out:
#    Num1  Num2  Num3  Num4
# 0   1.0     5     9  13.0
# 1   2.0     6    10  14.0

# %%
df_na.dropna(thresh=3)      # 删除包含缺失值的行，并指定非缺失值的数量
# Out:
#    Num1  Num2  Num3  Num4
# 0   1.0     5     9  13.0
# 1   2.0     6    10  14.0
# 3   4.0     8    12   NaN

# %%
import pandas as pd
import numpy as np
df_na = pd.DataFrame({'Num1':[1, 2, None, 4],
                      'Num2':[5, 6, 7, 8],
                      'Num3':[9, 10, 11, 12],
                      'Num4':[13, 14, np.nan, np.nan]})
df_na
# Out:
#    Num1  Num2  Num3  Num4
# 0   1.0     5     9  13.0
# 1   2.0     6    10  14.0
# 2   NaN     7    11   NaN
# 3   4.0     8    12   NaN

# %%
df_na.fillna(value=66.0)   # 使用标量66.0填充缺失值
# Out:
#    Num1  Num2  Num3  Num4
# 0   1.0     5     9  13.0
# 1   2.0     6    10  14.0
# 2  66.0     7    11  66.0
# 3   4.0     8    12  66.0

# %%
# 计算Num1列的平均数，并保留一位小数
mean_num1 = round(df_na['Num1'].mean(), 1)
mean_num1
# Out:
# np.float64(2.3)

# %%
# 计算Num4列的平均数，并保留一位小数
mean_num4 = round(df_na['Num4'].mean(), 1)
mean_num4
# Out:
# np.float64(13.5)

# %%
df_na.fillna(value={'Num1':mean_num1, 'Num4':mean_num4})
# Out:
#    Num1  Num2  Num3  Num4
# 0   1.0     5     9  13.0
# 1   2.0     6    10  14.0
# 2   2.3     7    11  13.5
# 3   4.0     8    12  13.5

# %%
df_na.fillna(method='ffill')         # 采用前向填充的方式填充缺失值
# Out:
# C:\Users\pby\AppData\Local\Temp\ipykernel_1644\3329080356.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_na.fillna(method='ffill')         # 采用前向填充的方式填充缺失值
#    Num1  Num2  Num3  Num4
# 0   1.0     5     9  13.0
# 1   2.0     6    10  14.0
# 2   2.0     7    11  14.0
# 3   4.0     8    12  14.0

# %%
df_na.fillna(method='bfill')  # 采用后向填充的方式填充缺失值
# Out:
# C:\Users\pby\AppData\Local\Temp\ipykernel_1644\3926686581.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_na.fillna(method='bfill')  # 采用后向填充的方式填充缺失值
#    Num1  Num2  Num3  Num4
# 0   1.0     5     9  13.0
# 1   2.0     6    10  14.0
# 2   4.0     7    11   NaN
# 3   4.0     8    12   NaN

# %% [markdown]
# ### 4.1.3	重复值的检测

# %%
import pandas as pd
person_info = pd.DataFrame({'name':['张三', '李四', '王五', '赵六', '赵六', '孙七'], 
                            'age': [24, 23, 29, 22, 22, 27], 'height': [162, 165, 175, 175, 175, 180], 'gender': ['女', '女', '男', '男', '男', '男']})
person_info
# Out:
#   name  age  height gender
# 0   张三   24     162      女
# 1   李四   23     165      女
# 2   王五   29     175      男
# 3   赵六   22     175      男
# 4   赵六   22     175      男
# 5   孙七   27     180      男

# %%
# 检测重复值，保留第一次出现的行，标记再次出现的其他行为重复值
person_info.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# dtype: bool

# %% [markdown]
# ### 4.1.4	重复值的处理

# %%
person_info.drop_duplicates()   # 删除重复值
# Out:
#   name  age  height gender
# 0   张三   24     162      女
# 1   李四   23     165      女
# 2   王五   29     175      男
# 3   赵六   22     175      男
# 5   孙七   27     180      男

# %% [markdown]
# ### 4.1.5	异常值的检测

# %% [markdown]
# #### 1．通过3σ原则检测异常值

# %%
import numpy as np
import pandas as pd
def three_sigma(ser):
    """
    :param ser: 被检测的数据，接收DataFrame类的对象的一列数据
    :return: 异常值及其对应的行索引
    """
    # 计算平均值
    mean_data = ser.mean()
    # 计算标准差
    std_data = ser.std()
    #小于μ-3σ或大于μ+3σ的数值均为异常值
    rule = (mean_data-3*std_data>ser) | (mean_data+3*std_data<ser)
    # 返回异常值的行索引
    index = np.arange(ser.shape[0])[rule]
    # 获取异常值
    outliers = ser.iloc[index]
    return outliers

# %%
import pandas as pd
df_obj = pd.read_csv(r'outlier_data.csv')
df_obj
# Out:
#      A  B
# 0    1  2
# 1    2  3
# 2    3  8
# 3    4  5
# 4    5  6
# 5    6  7
# 6   30  8
# 7    3  9
# 8    3  0
# 9    4  3
# 10   5  4
# 11   3  5
# 12   2  6
# 13   4  7
# 14   5  2
# 15  23  4
# 16   2  5
# 17   5  6
# 18   3  4

# %%
three_sigma (df_obj['A'])
# Out:
# 6    30
# Name: A, dtype: int64

# %%
three_sigma(df_obj['B'])
# Out:
# Series([], Name: B, dtype: int64)

# %% [markdown]
# #### 2．通过箱形图检测异常值

# %%
df_obj = pd.read_csv(r'example_data.csv')
df_obj.boxplot(column=['A', 'B'])   # 绘制箱形图
# Out:
# <Axes: >

# %%
import numpy as np
def box_outliers(ser):
    # 对待检测的数据集进行排序
    new_ser = ser.sort_values()
    # 判断数据的总数量是奇数还是偶数
    if new_ser.count() % 2 == 0:
        # 计算Q3、Q1、IQR
        Q3 = new_ser[int(len(new_ser) / 2):].median()
        Q1 = new_ser[:int(len(new_ser) / 2)].median()
    elif new_ser.count() % 2 != 0:
        Q3 = new_ser[int((len(new_ser)-1) / 2):].median()
        Q1 = new_ser[:int((len(new_ser)-1) / 2)].median()
    IQR = round(Q3 - Q1, 1)
    rule = (round(Q3+1.5*IQR, 1) < ser)|(round(Q1-1.5*IQR, 1) > ser)
    index = np.arange(ser.shape[0])[rule]
    # 获取异常值及其索引
    outliers = ser.iloc[index]
    return outliers

# %%
box_outliers(df_obj['A'])
# Out:
# 5     50
# 15    23
# Name: A, dtype: int64

# %% [markdown]
# ### 4.1.6	异常值的处理

# %%
df_obj.replace(to_replace=23, value=3)   # 替换一个异常值
# Out:
#      A  B
# 0    1  2
# 1    2  3
# 2    3  8
# 3    4  5
# 4    5  6
# 5   50  7
# 6    2  8
# 7    3  9
# 8    3  0
# 9    4  3
# 10   5  4
# 11   3  5
# 12   2  6
# 13   4  7
# 14   5  2
# 15   3  4
# 16   2  5
# 17   5  6
# 18   3  4

# %%
df_obj.replace(to_replace=[23, 50], value=[3, 2])   # 替换多个异常值
# Out:
#     A  B
# 0   1  2
# 1   2  3
# 2   3  8
# 3   4  5
# 4   5  6
# 5   2  7
# 6   2  8
# 7   3  9
# 8   3  0
# 9   4  3
# 10  5  4
# 11  3  5
# 12  2  6
# 13  4  7
# 14  5  2
# 15  3  4
# 16  2  5
# 17  5  6
# 18  3  4

# %% [markdown]
# ### 4.1.7	更改数据类型

# %%
import pandas as pd
df = pd.DataFrame({'A': ['1', '1.2', '4.2'],
                       'B': ['-9', '70', '88'],
                        'C': ['x', '5.0', '0']})
df.dtypes
# Out:
# A    object
# B    object
# C    object
# dtype: object

# %%
df['B'].astype(dtype='int')  # 强制转换为int类型
# Out:
# 0    -9
# 1    70
# 2    88
# Name: B, dtype: int64

# %%
import pandas as pd
ser_obj = pd.Series(['1.5', '2.2', '3.8'])
ser_obj
# Out:
# 0    1.5
# 1    2.2
# 2    3.8
# dtype: object

# %%
# 将object类型转换为float类型
pd.to_numeric(ser_obj)
# Out:
# 0    1.5
# 1    2.2
# 2    3.8
# dtype: float64

# %%
# 重新将末尾的数值改成字符串
ser_obj[2] = 'problem'
# 再次将object类型转换为float类型
pd.to_numeric(ser_obj)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/lib.pyx:2407, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "problem"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 4
#       2 ser_obj[2] = 'problem'
#       3 # 再次将object类型转换为float类型
# ----> 4 pd.to_numeric(ser_obj)
#
# File c:\Users\pby\anaconda3\envs\myenv\Lib\site-packages\pandas\core\tools\numeric.py:235, in to_numeric(arg, errors, downcast, dtype_backend)
#     233 coerce_numeric = errors not in ("ignore", "raise")
#     234 try:
# --> 235     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     236         values,
#     237         set(),
#     238         coerce_numeric=coerce_numeric,
#     239         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     240         or isinstance(values_dtype, StringDtype)
#     241         and values_dtype.na_value is libmissing.NA,
#     242     )
#     243 except (ValueError, TypeError):
#     244     if errors == "raise":
#
# File pandas/_libs/lib.pyx:2449, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "problem" at position 2

# %%
# 忽略非数字的值
pd.to_numeric(ser_obj, errors='ignore')
# Out:
# C:\Users\pby\AppData\Local\Temp\ipykernel_1644\379094108.py:2: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   pd.to_numeric(ser_obj, errors='ignore')
# 0        1.5
# 1        2.2
# 2    problem
# dtype: object

# %%
# 将非数字的值设置成NaN
pd.to_numeric(ser_obj, errors ='coerce')
# Out:
# 0    1.5
# 1    2.2
# 2    NaN
# dtype: float64

# %% [markdown]
# ## 4.2	数据合并

# %% [markdown]
# ### 4.2.1	堆叠合并

# %%
import pandas as pd
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                        'B': ['B0', 'B1', 'B2'],
                        'C': ['C0', 'C1', 'C2']})
df2 = pd.DataFrame({'C': ['C3', 'C4', 'C5', 'C6'],
                        'D': ['D0', 'D1', 'D2', 'D3']})
# 采用横向堆叠、外连接的方式合并df1和df2
result = pd.concat([df1, df2], join='outer', axis=1)
result
# Out:
#      A    B    C   C   D
# 0   A0   B0   C0  C3  D0
# 1   A1   B1   C1  C4  D1
# 2   A2   B2   C2  C5  D2
# 3  NaN  NaN  NaN  C6  D3

# %%
import pandas as pd
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                    'B': ['B0', 'B1', 'B2'],
                    'C': ['C0', 'C1', 'C2']})
df2 = pd.DataFrame({'C': ['C3', 'C4', 'C5', 'C6'],
                    'D': ['D0', 'D1', 'D2', 'D3']})
# 采用纵向堆叠、内连接的方式合并df1和df2
result = pd.concat([df1, df2], join='inner', axis=0)
result
# Out:
#     C
# 0  C0
# 1  C1
# 2  C2
# 0  C3
# 1  C4
# 2  C5
# 3  C6

# %% [markdown]
# ### 4.2.2	主键合并

# %%
import pandas as pd
left = pd.DataFrame({'key': ['K0', 'K1', 'K2'], 'A': ['A0', 'A1', 'A2'],
'B': ['B0', 'B1', 'B2']})
right = pd.DataFrame({'key': ['K0', 'K2', 'K3', 'K5'], 
'A': ['A0', 'A1', 'A2', 'A3'], 'C': ['C0', 'C1', 'C2', 'C3']})
# 根据key列，采用内连接的方式合并left和right
result = pd.merge(left=left, right=right, on='key')
result
# Out:
#   key A_x   B A_y   C
# 0  K0  A0  B0  A0  C0
# 1  K2  A2  B2  A1  C1

# %%
# 根据key列和A列，采用内连接的方式合并left和right
result = pd.merge(left=left, right=right, on=['key', 'A'])
result
# Out:
#   key   A   B   C
# 0  K0  A0  B0  C0

# %%
import pandas as pd
left = pd.DataFrame({'key': ['K0', 'K1', 'K2'], 'A': ['A0', 'A1', 'A2'],'B': ['B0', 'B1', 'B2']})
right = pd.DataFrame({'key': ['K0', 'K2', 'K3', 'K5'], 'A': ['A0', 'A1', 'A2', 'A3'], 'C': ['C0', 'C1', 'C2', 'C3']})
# 根据key列，采用全外连接的方式合并left和right
result = pd.merge(left=left, right=right, on='key', how='outer')
result
# Out:
#   key  A_x    B  A_y    C
# 0  K0   A0   B0   A0   C0
# 1  K1   A1   B1  NaN  NaN
# 2  K2   A2   B2   A1   C1
# 3  K3  NaN  NaN   A2   C2
# 4  K5  NaN  NaN   A3   C3

# %%
# 根据key列，采用左连接的方式合并left和right
result = pd.merge(left=left, right=right, on='key', how='left')
result
# Out:
#   key A_x   B  A_y    C
# 0  K0  A0  B0   A0   C0
# 1  K1  A1  B1  NaN  NaN
# 2  K2  A2  B2   A1   C1

# %%
import pandas as pd
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],'B': ['B0', 'B1', 'B2']})
left
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2

# %%
right = pd.DataFrame({'C': ['C0', 'C1', 'C2'], 'D': ['D0', 'D1', 'D2']}, 
                         index=['a', 'b', 'c'])
right
# Out:
#     C   D
# a  C0  D0
# b  C1  D1
# c  C2  D2

# %%
result = pd.merge(left=left, right=right, how='outer', 
                     left_index=True, right_index=True)
result
# Out:
#      A    B    C    D
# 0   A0   B0  NaN  NaN
# 1   A1   B1  NaN  NaN
# 2   A2   B2  NaN  NaN
# a  NaN  NaN   C0   D0
# b  NaN  NaN   C1   D1
# c  NaN  NaN   C2   D2

# %% [markdown]
# ### 4.2.3	根据索引合并

# %%
import pandas as pd
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'], 'B': ['B0', 'B1', 'B2']})
right = pd.DataFrame({'C': ['C0', 'C1', 'C2'], 'D': ['D0', 'D1', 'D2']},
                     index=[ 'a','b','c'])
# 采用左连接的方式根据索引合并left和right
result = left.join(right)
result
# Out:
#     A   B    C    D
# 0  A0  B0  NaN  NaN
# 1  A1  B1  NaN  NaN
# 2  A2  B2  NaN  NaN

# %%
# 采用外连接的方式根据索引合并left和right
result = left.join(right, how='outer')
result
# Out:
#      A    B    C    D
# 0   A0   B0  NaN  NaN
# 1   A1   B1  NaN  NaN
# 2   A2   B2  NaN  NaN
# a  NaN  NaN   C0   D0
# b  NaN  NaN   C1   D1
# c  NaN  NaN   C2   D2

# %%
import pandas as pd
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'], 'B': ['B0', 'B1', 'B2'],
                     'key': ['K0', 'K1', 'K2']})
right = pd.DataFrame({'C': ['C0', 'C1','C2'], 'D': ['D0', 'D1','D2']},
                     index=['K0', 'K1','K2'])
# 合并left和right，指定要连接的列
result = left.join(right, how='left', on='key')
result
# Out:
#     A   B key   C   D
# 0  A0  B0  K0  C0  D0
# 1  A1  B1  K1  C1  D1
# 2  A2  B2  K2  C2  D2

# %% [markdown]
# ### 4.2.4	合并重叠数据

# %%
import pandas as pd
import numpy as np
from numpy import nan
left = pd.DataFrame({'A': [np.nan, 'A1', 'A2', 'A3'],
                         'B': [np.nan, 'B1', np.nan, 'B3'],
                         'key': ['K0', 'K1', 'K2', 'K3']})
right = pd.DataFrame({'A': ['C0', 'C1','C2'],
                         'B': ['D0', 'D1','D2']},
                         index=[1,0,2])
# 用right填充left缺失的部分
left.combine_first(right)
# Out:
#     A   B key
# 0  C1  D1  K0
# 1  A1  B1  K1
# 2  A2  D2  K2
# 3  A3  B3  K3

# %% [markdown]
# ## 4.3	数据重塑

# %% [markdown]
# ### 4.3.1	重塑分层索引

# %%
import pandas as pd
df = pd.DataFrame({'A':['A0','A1','A2'],
                       'B':['B0','B1','B2']})
# 重塑df对象
result = df.stack()
result
# Out:
# 0  A    A0
#    B    B0
# 1  A    A1
#    B    B1
# 2  A    A2
#    B    B2
# dtype: object

# %%
type(result)
# Out:
# pandas.core.series.Series

# %%
result.unstack()      #　重塑result对象
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.array([[26,20,22,26],[30,25,24,20]]),
                     index=['男生人数','女生人数'],
                    columns=[['一楼','一楼','二楼','二楼'],
                               ['A教室','B教室','A教室','B教室']])
df.stack()
# Out:
# C:\Users\pby\AppData\Local\Temp\ipykernel_1644\742340218.py:7: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack()
#           一楼  二楼
# 男生人数 A教室  26  22
#      B教室  20  26
# 女生人数 A教室  30  24
#      B教室  25  20

# %%
df.stack(level=0)   # 旋转外层索引
# Out:
# C:\Users\pby\AppData\Local\Temp\ipykernel_1644\1700655.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack(level=0)   # 旋转外层索引
#          A教室  B教室
# 男生人数 一楼   26   20
#      二楼   22   26
# 女生人数 一楼   30   25
#      二楼   24   20

# %% [markdown]
# ### 4.3.2	轴向旋转

# %%
import pandas as pd
df =  pd.DataFrame({'商品名称': ['荣耀9青春版','小米6x','OPPO A1','荣耀9青春版','小米6x','OPPO A1'],
                    '出售日期': ['2023年5月25日', '2023年5月25日','2023年5月25日','2023年6月18日','2023年6月18日', '2023年6月18日'],
                    '价格': ['999元', '1399元', '1399元','800元', '1200元', '1250元']})
df.pivot(index='出售日期', columns='商品名称', values='价格')
# Out:
# 商品名称       OPPO A1   小米6x 荣耀9青春版
# 出售日期
# 2023年5月25日   1399元  1399元   999元
# 2023年6月18日   1250元  1200元   800元

# %% [markdown]
# ## 4.4	数据转换

# %% [markdown]
# ### 4.4.1	面元划分

# %%
import pandas as pd
ages = pd.Series([19, 21, 25, 55, 30, 45, 52, 46, 20])
bins = [0, 18, 30, 40, 50, 100]
# 使用cut函数划分年龄区间
cuts = pd.cut(ages, bins)
print(cuts)
# Out:
# 0     (18, 30]
# 1     (18, 30]
# 2     (18, 30]
# 3    (50, 100]
# 4     (18, 30]
# 5     (40, 50]
# 6    (50, 100]
# 7     (40, 50]
# 8     (18, 30]
# dtype: category
# Categories (5, interval[int64, right]): [(0, 18] < (18, 30] < (30, 40] < (40, 50] < (50, 100]]

# %% [markdown]
# ### 4.4.2	哑变量处理

# %%
import pandas as pd
df1 = pd.DataFrame({'职业': ['工人', '学生', '司机', '教师', '导游']})
pd.get_dummies(df1, prefix=['col_'])  # 哑变量处理
# Out:
#    col__司机  col__学生  col__导游  col__工人  col__教师
# 0    False    False    False     True    False
# 1    False     True    False    False    False
# 2     True    False    False    False    False
# 3    False    False    False    False     True
# 4    False    False     True    False    False

# %% [markdown]
# ## 预处理成都市二手房数据

# %%
import pandas as pd
import numpy as np
# 读取第一张表的数据
houses_one = pd.read_excel(r'C:\Users\pby\Downloads\Python数据分析与应用\.ipynb_checkpoints\secondhandhouse_one.xlsx')

# %%
# 查看houses_one的摘要信息
houses_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   区         500 non-null    object
#  1   小区名称      499 non-null    object
#  2   标题        500 non-null    object
#  3   房屋信息      500 non-null    object
#  4   关注        500 non-null    object
#  5   地铁        211 non-null    object
#  6   单价(元/平米)  500 non-null    object
# dtypes: object(7)
# memory usage: 27.5+ KB

# %%
# 读取第二张表的数据
houses_two = pd.read_excel(r'C:\Users\pby\Downloads\Python数据分析与应用\.ipynb_checkpoints\secondhandhouse_two.xlsx')
# 查看houses_two的摘要信息
houses_two.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558 entries, 0 to 557
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   区         558 non-null    object
#  1   小区名称      558 non-null    object
#  2   标题        558 non-null    object
#  3   房屋信息      558 non-null    object
#  4   关注        558 non-null    object
#  5   地铁        230 non-null    object
#  6   单价(元/平米)  558 non-null    float64
# dtypes: float64(1), object(6)
# memory usage: 30.6+ KB

# %%
# 把houses_one表里面“单价(元/平米)”一列的元字去掉
import re
old_values = []
new_values = []
for price_text in houses_one['单价(元/平米)']:
    result = re.findall('\d+.\d元$', str(price_text))
    if len(result) != 0:
        old_values.append(result[0])
        new_result = result[0][:-1]
        new_values.append(new_result)
new_house_one = houses_one.replace(to_replace=old_values, value=new_values)
# 转换“单价(元/平米)”一列数据的类型，由object转换为float
new_house_one['单价(元/平米)'] = new_house_one['单价(元/平米)'].astype(dtype='float')
new_house_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   区         500 non-null    object
#  1   小区名称      499 non-null    object
#  2   标题        500 non-null    object
#  3   房屋信息      500 non-null    object
#  4   关注        500 non-null    object
#  5   地铁        211 non-null    object
#  6   单价(元/平米)  500 non-null    float64
# dtypes: float64(1), object(6)
# memory usage: 27.5+ KB
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\pby\AppData\Local\Temp\ipykernel_1644\2545015451.py:6: SyntaxWarning: invalid escape sequence '\d'
#   result = re.findall('\d+.\d元$', str(price_text))

# %%
# 采用纵向堆叠、外连接的方式合并数据
final_house = pd.concat([new_house_one, houses_two])
final_house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1058 entries, 0 to 557
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   区         1058 non-null   object
#  1   小区名称      1057 non-null   object
#  2   标题        1058 non-null   object
#  3   房屋信息      1058 non-null   object
#  4   关注        1058 non-null   object
#  5   地铁        441 non-null    object
#  6   单价(元/平米)  1058 non-null   float64
# dtypes: float64(1), object(6)
# memory usage: 66.1+ KB

# %% [markdown]
# ### 1.	缺失值的检测与处理

# %%
def missing_values_table(df):
    # 计算每列包含缺失值的数量
    mis_val = df.isnull().sum()
    # 计算所有列缺失值⽐例
    mis_val_percent = df.isnull().sum() / len(df) * 100
    # 将数量和比例组合成DataFrame类的对象
    mis_val_table = pd.DataFrame({'数量':mis_val, 
                       '占比(%)':mis_val_percent})
    # 按照缺失值的数量降序排列
    mis_val_table_sorted = mis_val_table.sort_values('数量', 
                               ascending=False)
    return mis_val_table_sorted
missing_values_table(final_house)   # 统计缺失值的数量和占比情况
# Out:
#            数量      占比(%)
# 地铁        617  58.317580
# 小区名称        1   0.094518
# 区           0   0.000000
# 标题          0   0.000000
# 房屋信息        0   0.000000
# 关注          0   0.000000
# 单价(元/平米)    0   0.000000

# %%
# 删除小区名称一列的缺失值
final_house = final_house.dropna(subset=['小区名称'])
print(final_house)
# Out:
#       区      小区名称                         标题  \
# 0    锦江     翡翠城四期  翡翠城四期跃层 采光视野好 可看沙河 客厅带有阳台
# 1    锦江    时代豪庭一期   时代豪庭套三 中间楼层 有装修 业主处理资产出售
# 2    锦江     卓锦城六期         卓锦城六期紫郡房源，套三，进门带入户
# 3    锦江      星城银座        春熙路太古里标准套一出售，现租给民宿。
# 4    锦江      新莲新苑   新莲新苑优质套三，诚心出售，近沙河，采光视野好。
# ..   ..       ...                        ...
# 553  锦江      锦东庭园            锦东庭院居家套三  采光视野好
# 554  锦江  五世同堂街72号            五世同堂街72号 2室1厅 南
# 555  锦江  城市博客VC时代            锦江区红星路在售套一 标准套一
# 556  锦江    大地城市脉搏  春熙路大地城市脉搏 办公装修 二套打通生活交通方便
# 557  锦江    俊发星雅俊园        采光好，视野好，交通便利 楼下配套齐全
#
#                                          房屋信息              关注   地铁  单价(元/平米)
# 0      高楼层(共29层)| 2009年建 |2室1厅 | 85.21平米 | 东南   331人关注/ 5月前发布  近地铁  176036.0
# 1      中楼层(共38层)| 2009年建 |3室1厅 | 155.79平米| 东南   137人关注/ 5月前发布  NaN   26959.4
# 2       中楼层(共31层)| 2014年建 |3室1厅 | 89.33平米| 西南  36人关注 / 23天前发布  NaN   22612.8
# 3     高楼层(共11层) | 2003年建 | 1室0厅 | 51.07平米 | 南   29人关注 / 5月前发布  近地铁   18014.5
# 4      高楼层(共7层) | 2001年建 | 3室1厅 | 77.7平米 | 东南   14人关注 / 5月前发布  NaN   13513.5
# ..                                        ...             ...  ...       ...
# 553    高楼层(共34层) | 2015年建 | 3室2厅 | 113平米 | 东南   23人关注 / 1年前发布  近地铁   25663.7
# 554    高楼层(共7层) | 1995年建 | 2室1厅 | 55.99平米 | 南    1人关注 / 9天前发布  近地铁   14288.3
# 555  高楼层(共33层) | 2009年建 | 1室1厅 | 46.69平米 | 东南   33人关注 / 1年前发布  近地铁   18205.2
# 556  中楼层(共20层) | 2004年建 | 2室1厅 | 75.73平米 | 东南    1人关注 / 6月前发布  近地铁   25089.1
# 557  中楼层(共37层) | 2015年建 | 1室1厅 | 35.91平米 | 西北    7人关注 / 4月前发布  NaN    8911.2
#
# [1057 rows x 7 columns]

# %% [markdown]
# ### 2.	重复值的检测与处理

# %%
# 对删除缺失值后的数据进行重复值检测
final_house.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 553    False
# 554    False
# 555    False
# 556    False
# 557    False
# Length: 1057, dtype: bool

# %%
# 显示二手房数据中的重复项
final_house[final_house.duplicated().values == True]
# Out:
#       区       小区名称                             标题  \
# 54   锦江     柳江新居五期          琉璃场柳江新居五期带装修套二，房东诚心出售
# 55   锦江       锦洲花园             此房是锦洲花园中庭跃层，顶楼带大花园
# 97   锦江       澳龙名城               澳龙名城标准套四双卫随时可看房！
# 98   锦江      嘉和园二期             锦江 川师 狮子山 嘉和园 套二出售
# 99   锦江      钢管厂五区           海椒市街15号标准套二，户型方正不临街。
# 100  锦江   水碾河路南46号                水碾河 底层 家带店 标准套二
# 101  锦江     蓝润锦江春天            蓝润锦江春天 标准套二  家具家电全带
# 102  锦江    宏济新路95号               装修很好的套二，拎包入住，相当新
# 129  锦江  绿地468公馆三期            绿地468公馆三期清水套二，户型方正。
# 254  锦江     沙河壹号一期      沙河壹号，房东诚心卖，高楼层，采光好，视野开阔！！
# 255  锦江      嘉和园一期              房东诚心出售，交通便利 配套齐全。
# 256  锦江     鑫苑名家二期         鑫苑名家套三住宅，居家装修，业主自住保养好。
# 257  锦江     鑫苑名家一期             鑫苑名家一期，套二带装修，中间楼层，
# 258  锦江     紫东梵谷二期                紫东丽景套二，户型方正，低楼层
# 259  锦江       世纪朝阳                九眼桥一环边世纪朝阳对中庭套三
# 260  锦江       天涯南苑               带屋顶花园 标准套三双卫 带阳台
# 261  锦江       中粮鸿云           此房是标准套二，户型方正，精装修，未住人
# 262  锦江        创意山              创意山公寓，单价便宜，交通方便出行
# 263  锦江       总府花园            总府花园  有电梯  看房需要提前预约
# 349  锦江     蓝润锦江春天            蓝润锦江春天套三，东北朝向，看房预约。
# 350  锦江   西部国际金融中心      西部国际高品质小区，开发商统一装修，保养好，采光好
# 477  锦江       海桐二期           海桐二期居家套一，客厅带阳台，卧室带飘窗
# 478  锦江      翡翠城四期            翡翠城四期套二双卫，中间楼层，视野好。
# 479  锦江   锦江城市花园二期       锦江区 三圣乡 锦江城市花园二期，房东诚心出售！
# 169  锦江       华宇广场              华宇清水，诚心出售 有钥匙随时看房
# 170  锦江     鑫苑名家二期               鑫苑名家二期，装修套二，诚心出售
# 171  锦江   一环路东四段6号          一环路东四段6号目前仅有的一套诚心卖的房子
# 172  锦江   东安北左街21号         东安北左街21号，小区独门独院，安静不临街。
# 173  锦江       紫东梵谷               锦江区三环内商品房小高层标准套二
# 174  锦江       城东雅郡         城东雅郡 标准套二 中庭位置 安静通透 3楼
# 175  锦江   水碾河南三街5号               中间楼层采光好，套二改套三带阳台
# 331  锦江      钢管厂五区      钢管厂五区中间楼层出售  户型方正不临街 适合居家
# 332  锦江   蓝润V客东都一期         此房高楼层，采光好，视野开阔，采光好，带阳台
# 333  锦江     晶蓝半岛一期                晶蓝大套四，中高楼层，户型实用
# 334  锦江       朝阳名宅            成都九眼桥1.5环朝阳名宅套三双卫出售
# 335  锦江       东城攻略           东城攻略，套一*套二房，户型方正，视野好
# 466  锦江   锦江城市花园二期                锦江城市花园精装套二，户型方正
# 467  锦江       东洪广厦                成都市锦江区三圣乡 精装修套二
# 468  锦江        金红园              金红园套一，有装修，高楼层，不临街
# 469  锦江   锦江城市花园二期                锦江二期 装修套二  中间楼层
# 470  锦江     天地自由星城                牛市口新小区，有装修，标准套一
# 471  锦江    望江橡树林一期                望江橡树林一期朝南套二，采光好
# 472  锦江       蜀都花园       全中庭套三  采光好 视野开阔  装修保养很不错
# 473  锦江   锦江城市花园二期             锦江城市花园二期，一楼套二，居家装修
# 474  锦江   中房优山PLUS       中房优山清水套四，带100平米左右花园，西北朝向
# 475  锦江     鑫苑名家二期             鑫苑名家高品质套一，房东自住，诚心卖
# 476  锦江   莲桂南路31号院            莲桂南路 龙舟路 高楼层套二，居家装修
# 477  锦江    双槐树街90号               双槐树90，有装修套三，户型方正
# 478  锦江     俊发星雅俊园  三圣乡 清水公寓 跃层  4.9米层高 水电三通 房东急售
# 479  锦江   人居锦尚春天B区              人居锦尚春天B区精装套二，户型方正
# 480  锦江     蓝润锦江春天            蓝润锦江春天      4.9层高公寓
# 481  锦江     铁狮门晶融汇            春熙路 IFS 看太古里两居 精装套二
# 482  锦江         朗御         开发商精装修一室一厅保养好此价格带标准大车位
# 483  锦江      国润新锦江                二环内板式结构小区，电梯小高层
# 484  锦江  绿地468公馆二期                视野开阔采光好，崭新精装套二！
# 485  锦江       莲花逸都                莲花逸都套一出售 双阳台有装修
# 486  锦江      翡翠城五期              翡翠城五期标准套二，精装，看东湖，
# 487  锦江     时代豪庭三期     时代豪庭三期    西南朝向  三居室  客厅带阳台
#
#                                              房屋信息              关注   地铁  \
# 54      低楼层(共18层) | 2010年建 | 2室1厅 | 80.97平米 | 南 北   58人关注 / 3月前发布  近地铁
# 55       高楼层(共6层) | 2004年建 | 3室2厅 | 124.68平米 | 西北  135人关注 / 5月前发布  NaN
# 97   低楼层(共16层) | 2009年建 | 4室2厅 | 116.58平米 | 东南 西北   95人关注 / 8月前发布  近地铁
# 98            低楼层(共6层) | 2002年建 | 2室2厅 | 74平米 | 东   19人关注 / 8月前发布  近地铁
# 99           高楼层(共7层) | 1988年建 | 2室1厅 | 82平米 | 东南   60人关注 / 1年前发布  NaN
# 100       低楼层(共6层) | 1998年建 | 2室1厅 | 56.28平米 | 东南   55人关注 / 4月前发布  近地铁
# 101      低楼层(共18层) | 2015年建 | 2室1厅 | 54.29平米 | 西南    7人关注 / 3月前发布  NaN
# 102       高楼层(共6层) | 1985年建 | 2室1厅 | 56.76平米 | 西南  123人关注 / 7月前发布  NaN
# 129         高楼层(共33层) | 2015年建 | 2室1厅 | 77平米 | 东南   78人关注 / 4月前发布  NaN
# 254       高楼层(共34层) | 2011年建 | 2室1厅 | 72.89平米 | 西  123人关注 / 8月前发布  近地铁
# 255    中楼层(共6层) | 2002年建 | 2室2厅 | 78.29平米 | 东南 西北   20人关注 / 6月前发布  近地铁
# 256       中楼层(共40层) | 2012年建 | 3室1厅 | 86.03平米 | 北   24人关注 / 3月前发布  NaN
# 257         高楼层(共34层) | 2011年建 | 2室1厅 | 79平米 | 东南   48人关注 / 4月前发布  NaN
# 258       低楼层(共6层) | 2008年建 | 2室2厅 | 83.25平米 | 东南   51人关注 / 1年前发布  NaN
# 259     高楼层(共26层) | 2005年建 | 3室1厅 | 126.65平米 | 东北   14人关注 / 3月前发布  NaN
# 260       高楼层(共7层) | 2000年建 | 3室2厅 | 154.13平米 | 东   39人关注 / 3月前发布  NaN
# 261         高楼层(共40层) | 2017年建 | 2室1厅 | 66平米 | 西南   90人关注 / 8月前发布  NaN
# 262       低楼层(共22层) | 2017年建 | 2室1厅 | 70.24平米 | 南    9人关注 / 5月前发布  NaN
# 263      低楼层(共30层) | 2000年建 | 3室1厅 | 98.55平米 | 西南   62人关注 / 9月前发布  近地铁
# 349      中楼层(共18层) | 2016年建 | 3室2厅 | 71.76平米 | 东北  137人关注 / 1年前发布  NaN
# 350               高楼层(共47层) 2室1厅 | 82.64平米 | 东 东北   2人关注 / 28天前发布  近地铁
# 477      中楼层(共18层) | 2010年建 | 1室1厅 | 50.18平米 | 东南   35人关注 / 1年前发布  NaN
# 478      高楼层(共29层) | 2009年建 | 2室1厅 | 96.57平米 | 东南   12人关注 / 9月前发布  近地铁
# 479      高楼层(共34层) | 2010年建 | 3室1厅 | 81.82平米 | 东南   20人关注 / 4月前发布  NaN
# 169         高楼层(共17层) | 2017年建 | 1室1厅 | 37平米 | 东南    2人关注 / 2月前发布  近地铁
# 170      中楼层(共34层) | 2012年建 | 2室1厅 | 64.62平米 | 东南   7人关注 / 24天前发布  NaN
# 171       高楼层(共7层) | 1995年建 | 2室1厅 | 59.43平米 | 东南    5人关注 / 6月前发布  近地铁
# 172        低楼层(共3层) | 1995年建 | 1室1厅 | 45.87平米 | 南   11人关注 / 7月前发布  近地铁
# 173       低楼层(共18层) | 2007年建 | 2室1厅 | 78.7平米 | 东南    4人关注 / 1月前发布  NaN
# 174          中楼层(共6层) | 2005年建 | 2室2厅 | 86平米 | 东南  35人关注 / 10月前发布  近地铁
# 175        高楼层(共4层) | 1988年建 | 2室1厅 | 60.22平米 | 南   32人关注 / 9月前发布  近地铁
# 331       中楼层(共7层) | 2001年建 | 2室1厅 | 69.54平米 | 东南   29人关注 / 5月前发布  近地铁
# 332      中楼层(共35层) | 2017年建 | 2室1厅 | 56.17平米 | 东南    7人关注 / 3月前发布  近地铁
# 333        高楼层(共26层) | 2007年建 | 4室2厅 | 158平米 | 东南   13人关注 / 3月前发布  NaN
# 334      低楼层(共18层) | 2003年建 | 3室1厅 | 125.89平米 | 南    9人关注 / 2月前发布  NaN
# 335      中楼层(共33层) | 2008年建 | 1室1厅 | 51.83平米 | 西南   39人关注 / 1年前发布  NaN
# 466       中楼层(共34层) | 2010年建 | 2室1厅 | 65.09平米 | 北    9人关注 / 5月前发布  NaN
# 467       中楼层(共32层) | 2013年建 | 2室1厅 | 75.17平米 | 东    8人关注 / 4月前发布  NaN
# 468        高楼层(共7层) | 2003年建 | 1室1厅 | 51.61平米 | 北   21人关注 / 1年前发布  近地铁
# 469      高楼层(共34层) | 2010年建 | 2室1厅 | 72.08平米 | 东北    1人关注 / 7月前发布  NaN
# 470      中楼层(共24层) | 2015年建 | 1室1厅 | 51.31平米 | 西北   44人关注 / 1年前发布  NaN
# 471        低楼层(共34层) | 2009年建 | 2室1厅 | 82.5平米 | 南    6人关注 / 3月前发布  NaN
# 472     高楼层(共18层) | 2003年建 | 3室2厅 | 138.96平米 | 西北    6人关注 / 3月前发布  NaN
# 473         低楼层(共34层) | 2010年建 | 2室1厅 | 51平米 | 东南    3人关注 / 4月前发布  NaN
# 474        高楼层(共32层) | 2018年建 | 4室1厅 | 120平米 | 西北   20人关注 / 6月前发布  近地铁
# 475      高楼层(共34层) | 2012年建 | 1室1厅 | 48.84平米 | 东南    9人关注 / 1年前发布  NaN
# 476       高楼层(共7层) | 1995年建 | 2室1厅 | 63.84平米 | 西南   10人关注 / 1年前发布  NaN
# 477      中楼层(共7层) | 2000年建 | 3室2厅 | 105.85平米 | 东南   25人关注 / 1年前发布  NaN
# 478       低楼层(共37层) | 2015年建 | 1室1厅 | 36.4平米 | 东南    8人关注 / 5月前发布  NaN
# 479       中楼层(共41层) | 2013年建 | 2室2厅 | 84.7平米 | 西南    3人关注 / 3月前发布  NaN
# 480                 中楼层(共20层) 1室1厅 | 54.28平米 | 东南    3人关注 / 1年前发布  NaN
# 481      低楼层(共40层) | 2013年建 | 2室2厅 | 94.52平米 | 东南    5人关注 / 4月前发布  近地铁
# 482         中楼层(共51层) | 2012年建 | 1室1厅 | 90平米 | 东南    6人关注 / 3月前发布  近地铁
# 483      低楼层(共13层) | 2005年建 | 1室1厅 | 49.34平米 | 东南   4人关注 / 11月前发布  NaN
# 484          高楼层(共29层) | 2015年建 | 2室1厅 | 77平米 | 南    5人关注 / 3月前发布  近地铁
# 485      中楼层(共34层) | 2009年建 | 1室1厅 | 49.42平米 | 东北    4人关注 / 2月前发布  近地铁
# 486       高楼层(共32层) | 2011年建 | 2室1厅 | 77.67平米 | 南   12人关注 / 3月前发布  NaN
# 487     低楼层(共34层) | 2010年建 | 3室1厅 | 173.86平米 | 西南    7人关注 / 5月前发布  NaN
#
#      单价(元/平米)
# 54    13832.3
# 55    19890.9
# 97    25561.8
# 98    12567.6
# 99    11097.6
# 100   12970.9
# 101   20261.6
# 102   13037.4
# 129   20324.7
# 254   18521.1
# 255   12517.6
# 256   20341.7
# 257   15569.6
# 258   13813.8
# 259   22108.2
# 260   20437.3
# 261   31515.2
# 262   10962.4
# 263   20801.6
# 349   18812.7
# 350   37512.1
# 477   13949.8
# 478   21331.7
# 479   18235.2
# 169   17567.6
# 170   18570.1
# 171   13629.5
# 172   26160.9
# 173   14231.3
# 174   18604.7
# 175   12288.3
# 331   12367.0
# 332   12818.2
# 333   31962.0
# 334   20653.0
# 335   15821.0
# 466   19357.8
# 467   16229.9
# 468   15113.4
# 469   18035.5
# 470   21438.3
# 471   24121.2
# 472   18710.4
# 473   21176.5
# 474   31666.7
# 475   16789.5
# 476   13001.3
# 477   18894.7
# 478   12362.6
# 479   15938.6
# 480   16212.2
# 481   42319.1
# 482   31111.1
# 483   17430.1
# 484   22727.3
# 485   21044.1
# 486   30900.0
# 487   36811.2

# %%
# 删除重复值，忽略原来的索引并重新设置索引
final_house = final_house.drop_duplicates(ignore_index=True)
print(final_house)
# Out:
#       区      小区名称                         标题  \
# 0    锦江     翡翠城四期  翡翠城四期跃层 采光视野好 可看沙河 客厅带有阳台
# 1    锦江    时代豪庭一期   时代豪庭套三 中间楼层 有装修 业主处理资产出售
# 2    锦江     卓锦城六期         卓锦城六期紫郡房源，套三，进门带入户
# 3    锦江      星城银座        春熙路太古里标准套一出售，现租给民宿。
# 4    锦江      新莲新苑   新莲新苑优质套三，诚心出售，近沙河，采光视野好。
# ..   ..       ...                        ...
# 994  锦江      锦东庭园            锦东庭院居家套三  采光视野好
# 995  锦江  五世同堂街72号            五世同堂街72号 2室1厅 南
# 996  锦江  城市博客VC时代            锦江区红星路在售套一 标准套一
# 997  锦江    大地城市脉搏  春熙路大地城市脉搏 办公装修 二套打通生活交通方便
# 998  锦江    俊发星雅俊园        采光好，视野好，交通便利 楼下配套齐全
#
#                                          房屋信息              关注   地铁  单价(元/平米)
# 0      高楼层(共29层)| 2009年建 |2室1厅 | 85.21平米 | 东南   331人关注/ 5月前发布  近地铁  176036.0
# 1      中楼层(共38层)| 2009年建 |3室1厅 | 155.79平米| 东南   137人关注/ 5月前发布  NaN   26959.4
# 2       中楼层(共31层)| 2014年建 |3室1厅 | 89.33平米| 西南  36人关注 / 23天前发布  NaN   22612.8
# 3     高楼层(共11层) | 2003年建 | 1室0厅 | 51.07平米 | 南   29人关注 / 5月前发布  近地铁   18014.5
# 4      高楼层(共7层) | 2001年建 | 3室1厅 | 77.7平米 | 东南   14人关注 / 5月前发布  NaN   13513.5
# ..                                        ...             ...  ...       ...
# 994    高楼层(共34层) | 2015年建 | 3室2厅 | 113平米 | 东南   23人关注 / 1年前发布  近地铁   25663.7
# 995    高楼层(共7层) | 1995年建 | 2室1厅 | 55.99平米 | 南    1人关注 / 9天前发布  近地铁   14288.3
# 996  高楼层(共33层) | 2009年建 | 1室1厅 | 46.69平米 | 东南   33人关注 / 1年前发布  近地铁   18205.2
# 997  中楼层(共20层) | 2004年建 | 2室1厅 | 75.73平米 | 东南    1人关注 / 6月前发布  近地铁   25089.1
# 998  中楼层(共37层) | 2015年建 | 1室1厅 | 35.91平米 | 西北    7人关注 / 4月前发布  NaN    8911.2
#
# [999 rows x 7 columns]

# %% [markdown]
# ### 3. 异常值的检测与处理

# %%
from matplotlib import pyplot as plt
# 设置中文显示
plt.rcParams['font.sans-serif'] = ['SimHei']
estate = final_house[final_house['小区名称'].values == '翡翠城四期' ]
box = estate.boxplot(column='单价(元/平米)')
plt.show()

# %%
def box_outliers(ser):
    # 对需要检测的数据集进行排序
    new_ser = ser.sort_values()
    # 判断数据的总数量是奇数还是偶数
    if new_ser.count() % 2 == 0:
        # 分别计算Q3、Q1、IQR
        Q3 = new_ser[int(len(new_ser) / 2):].median()
        Q1 = new_ser[:int(len(new_ser) / 2)].median()
    elif new_ser.count() % 2 != 0:
        Q3 = new_ser[int((len(new_ser)-1) / 2):].median()
        Q1 = new_ser[:int((len(new_ser)-1) / 2)].median()
    IQR = round(Q3 - Q1, 1)
    rule = (round(Q3+1.5 * IQR, 1)<ser) | (round(Q1-1.5 * IQR, 1) > ser)
    index = np.arange(ser.shape[0])[rule]
    # 获取包含异常值的数据
    outliers = ser.iloc[index]
    return outliers

# %%
# 定义一个列表，用于保存异常值所在的索引
outliers_index_list = []
for i in set(final_house['小区名称']):
    estate = final_house[final_house['小区名称'].values == i]
    outliers_index = box_outliers(estate['单价(元/平米)'])
    if len(outliers_index) != 0:
        # 将异常值的索引添加到列表中
        outliers_index_list.append(outliers_index.index.tolist())
# 将utliers_index_list由嵌套列表转换为单个列表
outliers_index_single_li = sum(outliers_index_list, [])

# %%
final_house.loc[[i for i in outliers_index_single_li]]
# Out:
#       区      小区名称                          标题  \
# 0    锦江     翡翠城四期   翡翠城四期跃层 采光视野好 可看沙河 客厅带有阳台
# 882  锦江  锦江城市花园二期          锦江城市花园二期，一楼套二，居家装修
# 573  锦江     卓锦城三期  一楼带25平左右花园，套二带书房，户型方正，没有浪费
# 609  锦江      星城银座          星城银座 通天然气 不临街 户型方正
# 519  锦江      东城攻略            二环内   中装套二  还带阳台
# 902  锦江      东城攻略        东城攻略    标准套二     高楼层
# 923  锦江      东城攻略       房子满两年，保养的比较好，可以直接拎包入住
# 343  锦江    蓝谷地三四期       蓝谷地三四期，标准套四精装修全面对小区中庭
# 719  锦江      蜀都花园   中庭套三 不临街看小区大绿化 装修保养佳 看房方便
# 881  锦江      蜀都花园    全中庭套三  采光好 视野开阔  装修保养很不错
# 568  锦江     钢管厂五区      钢管厂五区电梯套二户型方正不临街  适合居家
# 874  锦江   望江橡树林一期           望江橡树林一期 套四改套三 带露台
# 700  锦江      锦江逸家            套三双卫   精装修  拎包入住
# 474  锦江      东洪广厦             东洪广厦 3室2厅 东南 西北
# 356  锦江    沙河壹号二期     锦江区 双公园 沙河壹号三房双卫房型 居家精装
# 475  锦江  人居锦尚春天B区            人居锦尚春天B区 3室1厅 东南
# 779  锦江      澳龙名城        澳龙名城套二出售，房东住家装修，保养好！
# 373  锦江      东湖国际   东湖国际跃层带花园，装修保养好，直接入住，满五年！
# 336  锦江  比华利国际城二期    比华利国际城二期 自住装修 带入户花园 带大平台
#
#                                             房屋信息              关注   地铁  \
# 0         高楼层(共29层)| 2009年建 |2室1厅 | 85.21平米 | 东南   331人关注/ 5月前发布  近地铁
# 882        低楼层(共34层) | 2010年建 | 2室1厅 | 51平米 | 东南    3人关注 / 4月前发布  NaN
# 573     低楼层(共24层) | 2010年建 | 2室2厅 | 96.45平米 | 东南   67人关注 / 7月前发布  NaN
# 609     高楼层(共11层) | 2003年建 | 1室1厅 | 36.58平米 | 东南   20人关注 / 1年前发布  近地铁
# 519     高楼层(共18层) | 2008年建 | 2室1厅 | 64.64平米 | 东南  134人关注 / 1年前发布  近地铁
# 902     高楼层(共33层) | 2008年建 | 2室1厅 | 81.89平米 | 东南    9人关注 / 3月前发布  NaN
# 923       低楼层(共33层) | 2008年建 | 2室2厅 | 79.8平米 | 北   17人关注 / 1年前发布  NaN
# 343    中楼层(共13层) | 2008年建 | 4室2厅 | 183.48平米 | 东南   36人关注 / 1年前发布  NaN
# 719    低楼层(共26层) | 2003年建 | 3室2厅 | 115.13平米 | 东北   20人关注 / 1年前发布  近地铁
# 881    高楼层(共18层) | 2003年建 | 3室2厅 | 138.96平米 | 西北    6人关注 / 3月前发布  NaN
# 568     中楼层(共11层) | 2001年建 | 2室2厅 | 85.21平米 | 东南    3人关注 / 3月前发布  NaN
# 874    高楼层(共32层) | 2009年建 | 4室2厅 | 156.33平米 | 西南   12人关注 / 4月前发布  NaN
# 700  高楼层(共33层) | 2015年建 | 3室1厅 | 74.38平米 | 东北 东南    4人关注 / 5月前发布  NaN
# 474  中楼层(共32层) | 2013年建 | 3室2厅 | 90.04平米 | 东南 西北   2人关注 / 19天前发布  NaN
# 356      中楼层(共32层) | 2013年建 | 3室2厅 | 91.1平米 | 东南   49人关注 / 4月前发布  NaN
# 475        低楼层(共41层) | 2013年建 | 3室1厅 | 90平米 | 东南    6人关注 / 4月前发布  NaN
# 779     低楼层(共33层) | 2009年建 | 2室1厅 | 89.65平米 | 东南  17人关注 / 11月前发布  近地铁
# 373    高楼层(共33层) | 2012年建 | 4室2厅 | 142.01平米 | 东南   14人关注 / 7月前发布  NaN
# 336        低楼层(共26层) | 2011年建 | 2室1厅 | 77平米 | 东南    3人关注 / 7月前发布  近地铁
#
#      单价(元/平米)
# 0    176036.0
# 882   21176.5
# 573   17107.3
# 609   24603.6
# 519   12840.3
# 902   18683.6
# 923   18797.0
# 343   21255.7
# 719   19803.7
# 881   18710.4
# 568   15960.6
# 874   31983.6
# 700   34955.6
# 474   16825.9
# 356   23051.6
# 475   17777.8
# 779   29001.7
# 373   39433.8
# 336   30519.5

# %%
final_house.drop(0)
# Out:
#       区      小区名称                         标题  \
# 1    锦江    时代豪庭一期   时代豪庭套三 中间楼层 有装修 业主处理资产出售
# 2    锦江     卓锦城六期         卓锦城六期紫郡房源，套三，进门带入户
# 3    锦江      星城银座        春熙路太古里标准套一出售，现租给民宿。
# 4    锦江      新莲新苑   新莲新苑优质套三，诚心出售，近沙河，采光视野好。
# 5    锦江    俊发星雅俊园   星雅俊园优质平层公寓，业主精装修，套二带家具家电
# ..   ..       ...                        ...
# 994  锦江      锦东庭园            锦东庭院居家套三  采光视野好
# 995  锦江  五世同堂街72号            五世同堂街72号 2室1厅 南
# 996  锦江  城市博客VC时代            锦江区红星路在售套一 标准套一
# 997  锦江    大地城市脉搏  春熙路大地城市脉搏 办公装修 二套打通生活交通方便
# 998  锦江    俊发星雅俊园        采光好，视野好，交通便利 楼下配套齐全
#
#                                          房屋信息              关注   地铁  单价(元/平米)
# 1      中楼层(共38层)| 2009年建 |3室1厅 | 155.79平米| 东南   137人关注/ 5月前发布  NaN   26959.4
# 2       中楼层(共31层)| 2014年建 |3室1厅 | 89.33平米| 西南  36人关注 / 23天前发布  NaN   22612.8
# 3     高楼层(共11层) | 2003年建 | 1室0厅 | 51.07平米 | 南   29人关注 / 5月前发布  近地铁   18014.5
# 4      高楼层(共7层) | 2001年建 | 3室1厅 | 77.7平米 | 东南   14人关注 / 5月前发布  NaN   13513.5
# 5       低楼层(共37层) | 2015年建 | 2室1厅 | 59平米 | 西南   80人关注 / 4月前发布  NaN   13220.3
# ..                                        ...             ...  ...       ...
# 994    高楼层(共34层) | 2015年建 | 3室2厅 | 113平米 | 东南   23人关注 / 1年前发布  近地铁   25663.7
# 995    高楼层(共7层) | 1995年建 | 2室1厅 | 55.99平米 | 南    1人关注 / 9天前发布  近地铁   14288.3
# 996  高楼层(共33层) | 2009年建 | 1室1厅 | 46.69平米 | 东南   33人关注 / 1年前发布  近地铁   18205.2
# 997  中楼层(共20层) | 2004年建 | 2室1厅 | 75.73平米 | 东南    1人关注 / 6月前发布  近地铁   25089.1
# 998  中楼层(共37层) | 2015年建 | 1室1厅 | 35.91平米 | 西北    7人关注 / 4月前发布  NaN    8911.2
#
# [998 rows x 7 columns]
